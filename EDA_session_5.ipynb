# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\HPLAP\Downloads\Visadataset.csv")

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include ='object').columns
num_columns= visa_df.select_dtypes(exclude ='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **box plot**

# %% [markdown]
# - box plot is used to identify the outliers
#
# - outliers is an observation having huge positive value or huge negative value
#
# - q1=24p, q2=50p,q3=75p
#
# - IQR=inter quartile range=q3-q1
#
# - q3+1.5*iqr and q3-1.5*iqr

# %%
# read the prevailing wage data and plot the box plot

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.xlabel('Boxplot')
plt.ylabel('wages')
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
sns.boxplot(wage_data,orient='h')
plt.xlabel('Boxplot')
plt.ylabel('wages')
plt.show()

# %%
import seaborn as sns
# plt.figure(figsize=(8,5)) # x-axis is 8 units,5 units y-axis
sns.countplot(data=visa_df,
              x='prevailing',
              data=wage_data)
plt.title('Bar chat')
plt.figsize=(8,5)
plt.savefig('continents_bar_chart_using_seaborn.jpg')
# plt.savefig('continents_bar_chart_using_seaborn.jpg')
plt.show()
# Out:
#   Cell In[69], line 5
#     data=wage_data)
#     ^
# SyntaxError: keyword argument repeated: data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrame loading (adjust this to your actual data source)
# visa_df = pd.read_csv('your_file.csv')

# Print column names to verify
print(visa_df.columns)

# Print the first few rows of the DataFrame
print(visa_df.head())

# Create the histogram
plt.figure(figsize=(8, 5))
sns.histplot( x='prevailing_wage',data=visa_df, bins=20)  # Adjust 'prevailing' to the actual column name if necessary

# Add a title
plt.title('Histogram of Prevailing')

# Save the plot
plt.savefig('histogram_prevailing.jpg')

# Show the plot
plt.show()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# ...

# %%
#plot the histogram plot and box plot side by side

# %%
wage_data=visa_df['prevailing_wage']
plt.figure(figsize=(14,3))
plt.subplot(1,2,1)
plt.suptitle('comparision of histogram with Boxplot')
plt.hist(wage_data,bins=20)
plt.xlabel('Histogram')
plt.subplot(1,2,2)
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
plt.figure(figsize=(14,3))
plt.suptitle('comparision of histogram with Boxplot')
plt.subplot(1,2,1).hist(wage_data,bins=20)
plt.hist(wage_data,bins=20)
plt.xlabel('Histogram')
plt.subplot(1,2,2)
plt.boxplot(wage_data,vert=False)
plt.show()

# %% [markdown]
# # finding the outliers
#
# - we already know that outliers available less than
#
# - step:1
#          -calculate  q1=25p
#                     q2=50p
#                     q3=75p
# - step-2:
#
#         -calculate   IQR =q3-q1
#
# - step-3:
#
#        -calculate lb = q1-1.5*iqr
#        -calculate up = q2+1.5*iqr
# - step-4:
#
#        -con1=wage data<lb
#        -con2=wage data>ub
#        -con3=con1 or con2

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=wage_data<lb
con2=wage_data>ub
con3=con1|con2
outliers_data=wage_data[con3]
outliers_data
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=wage_data>lb
con2=wage_data<ub
con3=con1&con2
non_outliers_df=visa_df[con3]
non_outliers_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - we have two dataframe
#
# - visa_df : total data 25480
#
# - non_outliers_df= after removing outliers 25053

# %%
wage_data_non_outliers_df=non_outliers_df['prevailing_wage']
plt.figure(figsize=(14,3))
plt.suptitle('comparision of histogram with Boxplot')
plt.subplot(1,2,1).hist(wage_data_non_outliers_df,bins=20)
plt.xlabel('Histogram')
plt.subplot(1,2,2).boxplot(wage_data_non_outliers_df,vert=False)
plt.xlabel('Boxplot')
plt.show()

# %%
wage_data_non_outliers_df=non_outliers_df['prevailing_wage']
wage_data=visa_df['prevailing_wage']
plt.figure(figsize=(16,9))
plt.suptitle('comparision of histogram with Boxplot')
plt.subplot(1,2,1).hist(wage_data_non_outliers_df,bins=20)
plt.xlabel('Histogram')
plt.subplot(2,2,2).boxplot(wage_data_non_outliers_df,vert=False)
plt.xlabel('Boxplot')
plt.subplot(2,2,3).hist(wage_data,bins=20)
plt.xlabel('Histogram')
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.xlabel('Boxplot')
plt.show()

# %%
# fill the outliers of wage data with wage median
# 427 outliers 
# 427 should replace with median value
# again draw the plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming visa_df is your DataFrame and 'prevailing_wage' is the column of interest
wage_data = visa_df['prevailing_wage']

# Calculate the median wage
median_wage = wage_data.median()

# Calculate IQR (Interquartile Range) to detect outliers
Q1 = wage_data.quantile(0.25)
Q3 = wage_data.quantile(0.75)
IQR = Q3 - Q1

# Define outliers as values below (Q1 - 1.5 * IQR) or above (Q3 + 1.5 * IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Replace outliers with the median value
wage_data_filled = wage_data.apply(lambda x: median_wage if x < lower_bound or x > upper_bound else x)

# Plot the data
plt.figure(figsize=(16, 9))
plt.suptitle('Comparison of Wage Data Before and After Replacing Outliers')

# Original Data
plt.subplot(2, 2, 1)
plt.hist(wage_data, bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title('Histogram (Original)')
plt.xlabel('Wage')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
plt.boxplot(wage_data, vert=False)
plt.title('Boxplot (Original)')
plt.xlabel('Wage')

# Data with Outliers Replaced
plt.subplot(2, 2, 3)
plt.hist(wage_data_filled, bins=20, color='green', edgecolor='black', alpha=0.7)
plt.title('Histogram (Outliers Replaced)')
plt.xlabel('Wage')
plt.ylabel('Frequency')

plt.subplot(2, 2, 4)
plt.boxplot(wage_data_filled, vert=False)
plt.title('Boxplot (Outliers Replaced)')
plt.xlabel('Wage')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit title
plt.show()

# %%
########################### data ################################
wage_data_non_outliers_df=non_outliers_df['prevailing_wage']
wage_data=visa_df['prevailing_wage']
########################## non outliers ##########################
plt.figure(figsize=(14,8))
plt.hist(wage_data)
plt.hist(wage_data_non_outliers_df)
plt.show()

# %% [markdown]
# **How to deal the outliers**
#
# - 1.we can drop the outliers
#
#    - droping outliers is an easy task, but not recomended
#
#    - If you the outliers we are droping the rows
#
#    - Which means we are droping the other column values also
#
#    - May be some important information we might loose from other column values
#
#    - But in  industry if outlier percentage less than 2% of the total
#
#    - The number of outliers in pwage is 427
#
#    - The number of total observations are 25480
#
#    - The percentage is 1.67 which is less than 2%
#
# - 2.Fill with Median value
#
#     - We already know that outliers does not affect by median
#
#     - So it is the best practice to fill the outliers with median
#
# - 3.Capping or florring
#
#     - Instead of fill with median
#
#     - We can fill with certain values
#
#     - the outliers which are less than  LB fill with LB value
#
#     - the outliers which are greater than  UB fill with UB value
#
# - **Isolation Forest**
#
#   - Is ML model used to find the outliers and anamolies

# %% [markdown]
# **Fill With Median Values**

# %% [markdown]
# **np.where**
#
# - In numpy we have method called where
#
# - It takes three arguments
#
#   -1.condition
#
#   -2.value if caondition is True
#
#   -3.value if condition is False
#
# - It is applicable for only Binary if and else

# %%
for value in wage_data:
    print(value)
# Out:
# 592.2029
# 83425.65
# 122996.86
# 83434.03
# 149907.39
# 78252.14
# 53635.39
# 418.2298
# 74362.19
# 67514.76
# 83588.56
# 70813.09
# 28663.05
# 107196.03
# 220081.73
# 74108.02
# 3706.79
# 16132.61
# 150441.13
# 79948.12
# 71128.98
# 137694.98
# 45642.39
# 90108.38
# 71286.04
# 99489.65
# 86332.95
# 103029.33
# 40925.86
# 189190.48
# 79594.12
# 135866.13
# 72077.57
# 81921.18
# 225569.73
# 92421.92
# 2490.12
# 110817.26
# 50960.01
# 125336.9
# 39633.32
# 156326.33
# 43630.58
# 54614.42
# 28989.87
# 22924.91
# 61567.75
# 156251.17
# 86022.02
# 49565.37
# 66191.41
# 95623.2
# 115014.05
# 35018.04
# 230.8072
# 113799.64
# 85854.09
# 14174.04
# 47176.84
# 4949.28
# 67410.59
# 58791.58
# 103.2216
# 62591.57
# 102919.59
# 123468.56
# 82324.64
# 5319.49
# 153019.94
# 38059.89
# 230.327
# 61521.92
# 121316.5
# 122540.55
# 47170.76
# 330.3743
# 2927.34
# 107781.48
# 590.0203
# 194176.83
# 102073.81
# 113882.38
# 70778.82
# 84125.48
# 174014.59
# 34213.17
# 79813.05
# 113327.34
# 78893.64
# ...

# %%
list1=[]
for value in wage_data:
    if value<lb or value>ub:
        median=wage_data.median()
        list1.append(median)
    else:
        list1.append(value)

# %%
dict1={'Sub':['DS','DE','CS'],
      'marks':[100,200,300]}
df=pd.DataFrame(dict1)
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE    200
# 2  CS    300

# %%
#Q1) I want  to replace marks with 1,which are argument than 100
for i in df.marks:
    if i<100:
        l.append(list1)
    else:
        list1.append(i)

df['marks']
# Out:
# 0    100
# 1    200
# 2    300
# Name: marks, dtype: int64

# %%
for i in df.marks:
    if i>100:
        list1.append(list1)
    else:
        list1.append(i)

df['marks']
# Out:
# 0    100
# 1    200
# 2    300
# Name: marks, dtype: int64

# %%
# np.where(<condition>,<True>,<False>)
con=df['marks']>100
list1=np.where(con,1,df['marks'])
df['marks']=list1
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE      1
# 2  CS      1

# %%
wage_data=visa_df['prevailing_wage']
con1=wage_data<lb
con2=wage_data>ub
con=con1|con2
wage_median=wage_data.median()
list1=np.where(con,wage_median,wage_data)
list1
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
visa_df['prevailing_wage_update']=list1

# %%
plt.subplot(1,2,1).boxplot(visa_df['prevailing_wage_update'])
plt.subplot(1,2,2).hist(visa_df['prevailing_wage_update'])
# Out:
# (array([4580., 3368., 3890., 4369., 3507., 2860., 1643.,  706.,  295.,
#          262.]),
#  array([2.13670000e+00, 2.18113840e+04, 4.36206314e+04, 6.54298787e+04,
#         8.72391260e+04, 1.09048373e+05, 1.30857621e+05, 1.52666868e+05,
#         1.74476115e+05, 1.96285363e+05, 2.18094610e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.subplot(1,2,1).boxplot(visa_df['prevailing_wage'])
plt.subplot(1,2,2).hist(visa_df['prevailing_wage'])
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Bi variate analysis**
#
# - we already seen uni variate analysis
#
# - We performed the categorical columns analysis
#
#   - Frequency table(value counts)
#
#   - Bar chart
#
#   - Relative frequency table (value counts Normalization form)
#
#   - pie chart
#
# - we performed the numerical column analysis
#
#   - Histogram
#
#   - Distribution
#
#   - Box plot
#
#   - Outlier analysis
#
#   - Filling the outliers
#
# - Now we will do categorical-categorical Analysis
#
# - Numerical-Numerical analysis
#
# - Categorical-Numerical analysis

# %% [markdown]
# **Catogorical-Catogorical**

# %% [markdown]
# - Lets consider two columns
#
#   - Continent
#
#   - Case status

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# continent
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %% [markdown]
# **Task**
#
# - Find the certified observation continenet wise
#
# - Find the Denied obsevation continent wise

# %%
visa_df['continent'].unique()
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
# Step-1:Make the first condition continent=='Asia'
# Step-2:Make the second condition case_status=='certified'
# Step-3:Make the third condition ==con1&con2
# Step-4:Make the retrive dataframe =='Asia'

con1=visa_df['continent']=='Asia'
con2=visa_df['case_status']=='Certified'
con3=con1&con2
len(visa_df[con3])
# Out:
# 11012

# %%
continents=visa_df['continent'].unique()
for i in continents:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con3=con1&con2
    count=len(visa_df[con3])
    print(f'the number of  certified visas from {i} is :{count}')
# Out:
# the number of  certified visas from Asia is :11012
# the number of  certified visas from Africa is :397
# the number of  certified visas from North America is :2037
# the number of  certified visas from Europe is :2957
# the number of  certified visas from South America is :493
# the number of  certified visas from Oceania is :122

# %%
continents=visa_df['continent'].unique()
certified_list,denied_list=[],[]
for i in continents:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con3=visa_df['case_status']=='Denied'
    cert_con=con1&con2
    den_con=con1&con3
    count=len(visa_df[con3])
    cert_count=len(visa_df[cert_con])
    den_count=len(visa_df[den_con])
    print(f'the number of  certified visa from{i} is :{cert_count}')
    print(f'the number of  Denied visa from{i} is :{den_count}')
    certified_list.append(cert_count)
    denied_list.append(den_count)
# Out:
# the number of  certified visa fromAsia is :11012
# the number of  Denied visa fromAsia is :5849
# the number of  certified visa fromAfrica is :397
# the number of  Denied visa fromAfrica is :154
# the number of  certified visa fromNorth America is :2037
# the number of  Denied visa fromNorth America is :1255
# the number of  certified visa fromEurope is :2957
# the number of  Denied visa fromEurope is :775
# the number of  certified visa fromSouth America is :493
# the number of  Denied visa fromSouth America is :359
# the number of  certified visa fromOceania is :122
# the number of  Denied visa fromOceania is :70

# %%
df=pd.DataFrame(zip(continents,certified_list))
df
# Out:
#                0      1
# 0           Asia  11012
# 1         Africa    397
# 2  North America   2037
# 3         Europe   2957
# 4  South America    493
# 5        Oceania    122

# %%
continents
certified_list
cols=['Continents','Certified']
df1=pd.DataFrame(zip(continents,certified_list),columns=cols)
df1
# Out:
#       Continents  Certified
# 0           Asia      11012
# 1         Africa        397
# 2  North America       2037
# 3         Europe       2957
# 4  South America        493
# 5        Oceania        122

# %%
df1.plot(kind='bar')
# Out:
# <Axes: >

# %%
df1.plot(kind='line')
# Out:
# <Axes: >

# %%
cols=['Certified','Denied']
df2=pd.DataFrame(zip(certified_list,denied_list),
                 index=continents,
                 columns=cols)
df2
# Out:
#                Certified  Denied
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %%
df2.plot(kind='bar')
# Out:
# <Axes: >

# %%
df2.plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# **Cross tab**
#
# - The above  data frame we can make  by using a method **cross tab**
#
# - it is available in pandas
#
# - it takes two arguments
#
#     - index
#
#     - columns
#
# - In above data frame index column is**continent**
#
# - In above data frame Dataframe column is**case_status**

# %%
pd.crosstab(visa_df['continent'],visa_df['case_status'])
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
inx_column=visa_df['continent']
data_column=visa_df['case_status']
df4=pd.crosstab(visa_df['continent'],visa_df['case_status'])
df4
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
df4.plot(kind='line')
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# **Multivariate analysis**
#
# - Education
#
# - continent
#
# - case status
#
# - we alredy know from Asia there 11k accept visa
#
# - In that I want future break down based on education
#
# - here also pd.cross tab
#
#   - first fix your index of any one column out of three column
#
#   - Then keep two column in a list and pass as data column

# %%
idx_column=visa_df['continent']
data_column=[visa_df['education_of_employee'],
             visa_df['case_status']]
df5=pd.crosstab(idx_column,data_column)
df5
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
 'line' : line plot (default)
    - 'bar' : vertical bar plot
    - 'barh' : horizontal bar plot
    - 'hist' : histogram
    - 'box' : boxplot
    - 'kde' : Kernel Density Estimation plot
    - 'density' : same as 'kde'
    - 'area' : area plot
    - 'pie' : pie plot
    - 'scatter' : scatter plot (DataFrame only)
    - 'hexbin' : hexbin plot (DataFrame only)

# %%
df5.plot(kind='line')
# Out:
# <Axes: xlabel='continent'>

# %%
df5.plot(kind='barh')
# Out:
# <Axes: ylabel='continent'>

# %%
df5.plot(kind='box')
# Out:
# <Axes: >

# %%
df5.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df5.plot(kind='area')
# Out:
# <Axes: xlabel='continent'>
